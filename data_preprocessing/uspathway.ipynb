# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.DataFrame(pd.read_excel(r"F:\LPU\Data\Datasets\Internship datasets\UsPathway\US Pathway Complete Data.xlsx", sheet_name="campaign_performance"))
df1.head(10)
# Out:
#        dates                        campaign_name campaign_start_date  \
# 0 2024-04-29           USP_Search_APTNTSKA_250124                 NaT
# 1 2024-05-02  USP_2_Lead-gen-2_Top4-states_050424                 NaT
# 2 2024-05-02  USP_2_Lead-gen-2_Top4-states_050424                 NaT
# 3 2024-05-02  USP_2_Lead-gen-2_Top4-states_050424                 NaT
# 4 2024-05-02  USP_2_Lead-gen-2_Top4-states_050424                 NaT
# 5 2024-05-02  USP_2_Lead-gen-2_Top4-states_050424                 NaT
# 6 2024-05-02  USP_2_Lead-gen-2_Top4-states_050424                 NaT
# 7 2024-05-02      USP Study Abroad_Generic_240224                 NaT
# 8 2024-05-02  USP_2_Lead-gen-2_Top4-states_050424                 NaT
# 9 2024-05-02              USP_2_Lead-gen-1_220124                 NaT
#
#                        creative_name  total_spent  impressions  clicks  \
# 0                                 --      6766.15         1250     220
# ...

# %%
df1['campaign_start_date'].unique()
# Out:
# <DatetimeArray>
# ['NaT', '2023-11-09 00:00:00', '2023-11-24 00:00:00', '2024-03-22 00:00:00']
# Length: 4, dtype: datetime64[ns]

# %%
df1.loc[(df1['campaign_name'] == 'USP Study Abroad_Generic_240224') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2024-02-24'
df1.loc[(df1['campaign_name'] == 'USP_2_Lead-gen-1_220124') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2024-01-22'
df1.loc[(df1['campaign_name'] == 'USP_2_Lead-gen-2_Top4-states_050424') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2024-04-05'
df1.loc[(df1['campaign_name'] == 'USP_Marketing+MBA_New Leads Campaign_240224') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2024-02-24'
df1.loc[(df1['campaign_name'] == 'USP_MS + Coop Campaign_240224') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2024-02-24'
df1.loc[(df1['campaign_name'] == 'USP_Program_Higher Intent_No Logic_South-states_220124') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2024-01-24'
df1.loc[(df1['campaign_name'] == 'USP_Program_More-Volume_No Logic_India_220124') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2024-01-24'
df1.loc[(df1['campaign_name'] == 'USP_Search_APTNTSKA_250124') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2024-01-25'
df1.loc[(df1['campaign_name'] == 'USP_Video_APTLTSKA_Lead-Gen_Websites_050324') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2024-03-05'
df1.loc[(df1['campaign_name'] == 'USP_Webinar2_270324') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2024-03-27'
df1.loc[(df1['campaign_name'] == 'USP_Webinar_070324') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2024-03-07'
df1.loc[(df1['campaign_name'] == 'US_Pathway_2_Lead_gen_1_091123') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2023-11-09'
df1.loc[(df1['campaign_name'] == 'US_Pathway_2_Lead_gen_2_091123') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2023-11-09'
df1.loc[(df1['campaign_name'] == 'US_Pathway_2_Lead_gen_3_241123') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2023-11-24'
df1.loc[(df1['campaign_name'] == 'US_Pathway_2_Lead_gen_4_220324') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2024-03-22'
df1.loc[(df1['campaign_name'] == 'xCBO - USP Masterclass Cold [ 23rd Nov ] - More Volume - No Logic - India-  new link') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2023-11-23'
df1.loc[(df1['campaign_name'] == 'xCBO - USP Masterclass Cold [ 7th Dec ] - Higher Intent - No Logic -  new link India') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2023-12-07'
df1.loc[(df1['campaign_name'] == 'CBO - USP Masterclass Cold [ 15th Dec ] - Higher Intent - No Logic - India Â– new link') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2023-12-15'
df1.loc[(df1['campaign_name'] == 'CBO - USP Masterclass Cold [ 15th Dec ] - Higher Intent - No Logic - India Â– New Link') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2023-12-15'
df1.loc[(df1['campaign_name'] == 'CBO - USP Masterclass Cold [ 23rd Nov ] - Higher Intent - No Logic new-  India') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2023-11-23'
df1.loc[(df1['campaign_name'] == 'CBO - USP Masterclass Cold [ 23rd Nov ] - More volume - With Logic') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2023-11-23'
df1.loc[(df1['campaign_name'] == 'USP Masterclass Cold [ 31st Oct ] - Higher Intent - No Logic') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2023-10-31'
df1.loc[(df1['campaign_name'] == 'USP Masterclass Cold [ 31st Oct ] - More Volume - No Logic') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2023-10-31'

# %%
df1.loc[(df1['campaign_name'] == 'CBO - USP Masterclass Cold [ 15th Dec ] - More Volume - No Logic - India Â– New Link') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2023-12-15'
df1.loc[(df1['campaign_name'] == 'CBO - USP Masterclass Cold [ 15th Dec ] - More Volume - No Logic - India Â– New Link') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2023-12-15'
df1.loc[(df1['campaign_name'] == 'USP Masterclass Cold [ 23rd Nov ] - More volume - With Logic - India') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2023-11-23'
df1.loc[(df1['campaign_name'] == 'USP Masterclass Cold [ 31st Oct ] - More volume - With Logic') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2023-10-31'
df1.loc[(df1['campaign_name'] == 'USP_COOP-Drexel_More_Volume_No Logic_India_240124') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2024-01-24'
df1.loc[(df1['campaign_name'] == 'USP_Program_Higher Intent_No Logic_India_220124') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2024-01-22'
df1.loc[(df1['campaign_name'] == 'USP_Program_Lead-gen_2_Generic_140223') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2023-02-14'
df1.loc[(df1['campaign_name'] == 'USP_Program_Lead-gen_3_Co-op_140223') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2023-02-14'
df1.loc[(df1['campaign_name'] == 'USP_Program_Lead-gen_4_MAR&MBA_140223') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2023-02-14'
df1.loc[(df1['campaign_name'] == 'USP_Program_More-Volume_No Logic_South-states_220124') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2024-01-22'
df1.loc[(df1['campaign_name'] == 'USP_Program_More-volume_With-Logic_India_220124') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2024-01-22'
df1.loc[(df1['campaign_name'] == 'USP_Program_More-volume_With-Logic_South-states_220124') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2024-01-22'
df1.loc[(df1['campaign_name'] == 'USP_Search_India-ex-APTNTSKA_250124') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2024-01-25'
df1.loc[(df1['campaign_name'] == 'USP_Video_ALL-India_Lead-Gen_Keywords_110324') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2024-03-11'
df1.loc[(df1['campaign_name'] == 'USP_Video_APTLTSKA_Lead-Gen_160224') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2024-02-16'
df1.loc[(df1['campaign_name'] == 'USP_Video_APTLTSKA_Lead-Gen_Custom-intent_050324') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2024-03-05'
df1.loc[(df1['campaign_name'] == 'USP_Video_APTLTSKA_Lead-Gen_Keywords_050324') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2024-03-05'
df1.loc[(df1['campaign_name'] == 'USP_Video_India_EX-APTLTSKA_Lead-Gen_160224') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2024-02-16'

# %%
df1.loc[(df1['campaign_name'] == 'USP Masterclass Cold [ 14th Dec ] - Link Click Ad') & (df1['campaign_start_date'].isna()), 'campaign_start_date'] = '2023-12-14'

# %%
df1['campaign_start_date'].value_counts()
# Out:
# campaign_start_date
# 2024-02-24    6581
# 2023-11-23    3545
# 2023-10-31    3476
# 2024-01-22    3291
# 2023-11-09    2585
# 2024-01-24    2186
# 2023-11-24    1428
# 2023-12-15    1315
# 2023-02-14     989
# 2024-04-05     741
# 2024-03-07     444
# 2024-03-05     430
# 2024-03-22     234
# 2024-03-27     193
# 2024-01-25     185
# 2024-02-16     122
# 2023-12-07     103
# 2023-12-14      80
# 2024-03-11      20
# Name: count, dtype: int64

# %%
df1.to_excel('cleaned_campaign_performance.xlsx', index=False)

# %%
plt.scatter(df1['impressions'], df1['impressions'])

# %%
df2 = pd.DataFrame(pd.read_excel(r"F:\LPU\Data\Datasets\Internship datasets\UsPathway\US Pathway Complete Data.xlsx", sheet_name="Leads Generated"))
df2.head(10)
# Out:
#                                 lead_id        created_time  \
# 0                    l:3587545764833355 2024-05-02 14:18:00
# 1  cc0da387-682c-4530-a79a-1168487410f0 2024-04-30 18:00:07
# 2  10045c19-1c8d-4d63-a6bf-62d00a2f50ec 2024-03-21 02:25:55
# 3  7e0db362-ebc3-4265-9131-d69bae5eb3f5 2024-03-17 06:40:21
# 4  5f74bcc1-08a8-414d-a729-69d5071b4f53 2024-03-20 07:48:39
# 5  b646328e-e169-48b1-b2f0-486f2f60da20 2024-03-15 21:46:06
# 6  51737b98-7011-4066-b5c3-324173374fce 2024-03-15 17:50:29
# 7  0d2fb3f0-6bad-4c6a-9d44-b02f37d8c2c6 2024-01-26 19:47:29
# 8  9e9bc870-8ab6-4e6d-8128-03a3406a9648 2024-01-27 08:48:27
# 9  5a90b8f3-c021-4253-857b-d0394861bcf4 2024-02-25 12:04:24
#
#                     Ad Name                                Campaign Name  \
# 0  USP_S3_never-been-easier                      USP_2_Lead-gen-1_220124
# 1                        --                   USP_Search_APTNTSKA_250124
# 2                    Shreya  USP_Video_APTLTSKA_Lead-Gen_Keywords_050324
# ...

# %%
df2['lead_id'].duplicated().any()
# Out:
# np.False_

# %%
len(df2['Ad Name'].unique())
# Out:
# 135

# %%
len(df2['form_name'].unique())
# Out:
# 16

# %%
(df2['contacted'].unique())
# Out:
# array(['Contacted', nan], dtype=object)

# %%
df2['mapped'].isna().value_counts()
# Out:
# mapped
# False    32058
# True       711
# Name: count, dtype: int64

# %%
df2['contacted'].isna().value_counts()
# Out:
# contacted
# False    30805
# True      1964
# Name: count, dtype: int64

# %%
df2['graduation_degree'].unique()
# Out:
# array(['b.tech_cse', 'B.Tech CSE', 'PG', 'Others', 'UG',
#        'B.Tech (Civil, ME, ECE, EEE etc.)', 'MCA', 'B.Tech IT', 'others',
#        'B.Tech (Civil, EEE, Mech. , etc.)',
#        'b.tech_(civil,_eee,_mech._,_etc.)', 'm.tech', 'b.tech_it',
#        'b.tech_(mech,_civil,_e&tc,_etc.)', 'mca', 'M.Tech', nan,
#        'b.tech/be'], dtype=object)

# %%
df2['graduation_degree']=df2['graduation_degree'].replace('b.tech_cse', 'B.Tech CSE')
df2['graduation_degree']=df2['graduation_degree'].replace('others', 'Others')
df2['graduation_degree']=df2['graduation_degree'].replace('b.tech_it', 'B.Tech IT')
df2['graduation_degree']=df2['graduation_degree'].replace('m.tech', 'M.Tech')
df2['graduation_degree']=df2['graduation_degree'].replace('mca', 'MCA')
df2['graduation_degree']=df2['graduation_degree'].replace(['b.tech_(civil,_eee,_mech._,_etc.)', 'b.tech_(mech,_civil,_e&tc,_etc.)', 'b.tech_(mech,_civil,_e&tc,_etc.)'], 'B.Tech (Civil, EEE, Mech. , etc.)')

# %%
df2['graduation_degree'] = df2['graduation_degree'].replace('b.tech/be', 'B.TECH/BE')

# %%
df2['graduation_degree'].unique()
# Out:
# array(['B.Tech CSE', 'PG', 'Others', 'UG',
#        'B.Tech (Civil, ME, ECE, EEE etc.)', 'MCA', 'B.Tech IT',
#        'B.Tech (Civil, EEE, Mech. , etc.)', 'M.Tech', nan, 'B.TECH/BE'],
#       dtype=object)

# %%
plt.scatter(df2['graduation_percentage'], df2['graduation_percentage'])

# %%
df2['graduation_percentage'].isna().value_counts()
# Out:
# graduation_percentage
# False    32764
# True         5
# Name: count, dtype: int64

# %%
df2['work_experience'].unique()
# Out:
# array([7, '3 Years', '1 Year', 'Fresher', '10 Years', '5 Years',
#        '2 Years', '8 Years', '4 Years', '9 Years', '6 Years', '7 Years',
#        1, 2, 3, 4, 5, 'no_work_experience', 12, 6, 10, 15, 11, 8, 9, 14,
#        13, nan], dtype=object)

# %%
df2['work_experience'] = df2['work_experience'].astype(str).str.replace(' Years', '').str.replace(' Year', '')

# %%
df2['work_experience'] = df2['work_experience'].astype(str).str.replace('Fresher', '-1').str.replace('no_work_experience', '0')

# %%
df2['work_experience'].unique()
# Out:
# array(['7', '3', '1', '-1', '10', '5', '2', '8', '4', '9', '6', '0', '12',
#        '15', '11', '14', '13', 'nan'], dtype=object)

# %%
df2['work_experience'] = pd.to_numeric(df2['work_experience'], errors='coerce')

# %%
df2['work_experience'].dtypes
# Out:
# dtype('float64')

# %%
plt.scatter(df2['work_experience'], df2['work_experience'])

# %%
df2['lsq_lead_stage'].unique()
# Out:
# array(['Not Interested', nan, 'Invalid phone number', 'New Enquiry',
#        'Invalid', 'Not Eligible', 'Warm', 'Never Picked up',
#        'Waiting for Offer Letter', 'Uncontactable', 'Follow Up Required',
#        'Cold', 'Test', 'Hot', 'Connected/ Not Interested', 'Enrolled',
#        'Document Collection', 'Counselling Booked', 'Counselling Done',
#        'Not Eligible for the Course', 'Future Interest', 'DND',
#        'Application Filling', 'Wrong Number', 'Future Prospects',
#        'Token Amount', 'Application Rejected', 'Payment Received',
#        'Application Submitted', 'Duplicate Lead'], dtype=object)

# %%
df2['lsq_source'].unique()
# Out:
# array(['Facebook', nan, 'GoogleAds', 'LinkedIn', 'N-DB',
#        'B.Tech 19-20 Grad', 'Whatsapp External', 'Linkedin',
#        'XAT attended 2017', 'OS', 'Zoom Webinar', 8066170260,
#        'AP Btech graudate 2017', 'Placement Drive', 'Quick Add', 'DS 2+',
#        'WhatsApp Leads', 'Website', 'Mumbai 2017', 8066170298, 'Organic',
#        'US Pathway', '17th sept hot leads', 7969257059, 'Futurense Uni',
#        'IGOrganic', 'Times Jobs', 'Linkedin Inmail', 'IG', 8066170297,
#        8068228677, 'Futurense USP - Website', 7969257080, 8066170281,
#        'Calendly', 8066170264, 'LPU', 'Roadmap to DS Careers Webinar',
#        'Organic Search', 'Futurense IITJ Main Page', 'Inbound Phone call',
#        8066170286, 'Os2', 'N-DB 3+', 8066170292, '1% Club',
#        'US Pathway - Webinar', 'USP support', 'Instagram', 'Live Chat',
#        7969257031, 'TimesJobs'], dtype=object)

# %%
df2.drop('lead_id.1',axis=1)
# Out:
#                                       lead_id        created_time  \
# 0                          l:3587545764833355 2024-05-02 14:18:00
# 1        cc0da387-682c-4530-a79a-1168487410f0 2024-04-30 18:00:07
# 2        10045c19-1c8d-4d63-a6bf-62d00a2f50ec 2024-03-21 02:25:55
# 3        7e0db362-ebc3-4265-9131-d69bae5eb3f5 2024-03-17 06:40:21
# 4        5f74bcc1-08a8-414d-a729-69d5071b4f53 2024-03-20 07:48:39
# ...                                       ...                 ...
# 32764                      l:1287087698649474 2023-12-29 20:15:00
# 32765                       l:752743646765142 2024-01-24 13:37:00
# 32766                       l:701943358682733 2024-03-21 06:19:00
# 32767  ffd92ee8-f03c-4af0-a4a9-a0e47aff34dc-6 2024-01-04 03:45:00
# 32768                      l:1116793499325062 2024-02-01 14:03:00
#
#                                                  Ad Name  \
# 0                               USP_S3_never-been-easier
# ...

# %%
df3 = pd.DataFrame(pd.read_excel(r"F:\LPU\Data\Datasets\Internship datasets\UsPathway\US Pathway Complete Data.xlsx", sheet_name="Phone Metrics"))
df3.head(10)
# Out:
#    lead_number       first_name             Lead Id  \
# 0      2704878           Pranav   l:861701659054416
# 1      2288584     Ramakrishnan   l:966563021758786
# 2      2721420  Purnima kuppala   l:430457079653387
# 3       693703           Sambit                 NaN
# 4      2712125    Gokul Krishna  l:1547362259166875
# 5       700484    Chintan Patel   l:308522655285948
# 6      2710794         Himalaya  l:1150042865993500
# 7       915109        Sivananda  l:1545615879597516
# 8       819571           Ishant                 NaN
# 9      2274488           Vibhor                 NaN
#
#    inbound_phone_call_counter  mobile_number  outbound_phone_call_counter  \
# 0                         NaN            NaN                          NaN
# 1                         NaN            NaN                          NaN
# 2                         NaN            NaN                          NaN
# 3                         NaN            NaN                          NaN
# ...

# %%
df2['graduation_percentage'] = pd.to_numeric(df2['graduation_percentage'], errors='coerce')

# %%
df2['graduation_percentage'].dtypes
# Out:
# dtype('float64')

# %%
print(df3['new_followup'].unique())
print(df3['contacted'].unique())
print(df3['squad_role'].unique())
# print(df3['inbound_phone_call_counter'].unique())
# print(df3['outbound_phone_call_counter'].unique())

print(len(df3['inbound_phone_call_counter'].unique()))
print(len(df3['outbound_phone_call_counter'].unique()))
# Out:
# [nan 'new']
# [nan]
# ['Agent' 'TL' nan]
# 73
# 135

# %%
df3 = pd.DataFrame(pd.read_excel(r"F:\LPU\Data\Datasets\Internship datasets\UsPathway\US Pathway Complete Data.xlsx", sheet_name="Tokens Paid"))
df3.head(10)
# Out:
#        Name Lead ID created_date  paid_date    cohort              source  \
# 0   Saurabh     NaN   2024-03-01 2024-03-07  Cohort 2                 NaN
# 1   Sudheer     NaN   2023-08-25 2023-08-30  Cohort 1            LinkedIn
# 2    Swathi     NaN   2023-09-19 2023-10-06  Cohort 1            LinkedIn
# 3     Kabir     NaN   2024-03-21 2024-03-23  Cohort 2  Inbound Phone Call
# 4    Vikash     NaN   2023-08-05 2023-08-14  Cohort 1            LinkedIn
# 5      Amir     NaN   2023-08-07 2023-08-08  Cohort 1        Zoom Webinar
# 6      Syed     NaN   2024-04-28 2024-04-27  Cohort 2            Referral
# 7       Sam     NaN   2023-10-05 2023-10-09  Cohort 1          US Pathway
# 8    Ishaan     NaN   2023-10-08 2023-10-16  Cohort 1          US Pathway
# 9  Nandhini     NaN   2023-09-09 2023-10-03  Cohort 1            LinkedIn
#
#                agent        counsellor                           prospect_id  \
# ...

# %%
df3 = pd.DataFrame(pd.read_excel(r"F:\LPU\Data\Datasets\Internship datasets\UsPathway\US Pathway Complete Data.xlsx", sheet_name="Webinar Leads"))
df3.head(10)
# Out:
#   attended Leads ID       phone   registration_time approval_status join_time  \
# 0       No      NaN         NaN 2024-01-12 12:17:35        approved       NaT
# 1       No      NaN         NaN 2024-01-12 12:17:35        approved       NaT
# 2       No      NaN         NaN 2024-01-12 12:17:35        approved       NaT
# 3       No      NaN  7905033452 2023-11-03 10:18:57        approved       NaT
# 4       No      NaN  9642484731 2023-11-03 20:40:52        approved       NaT
# 5       No      NaN  7307373409 2023-11-08 11:44:58        approved       NaT
# 6       No      NaN  8073328902 2023-11-09 12:15:42        approved       NaT
# 7       No      NaN         NaN 2024-01-12 12:17:35        approved       NaT
# 8       No      NaN  7982285677 2023-11-07 11:16:53        approved       NaT
# 9       No      NaN  9632315686 2023-11-07 13:17:45        approved       NaT
#
#   leave_time  time_in_session is_guest country_region_name      source_name  \
# ...

# %%
df3 = pd.DataFrame(pd.read_excel(r"F:\LPU\Data\Datasets\Internship datasets\UsPathway\US Pathway Complete Data.xlsx", sheet_name="Candidate Application Tracker"))
df3.head(10)
# Out:
#   Unnamed: 0      Unnamed: 1         Unnamed: 2                  Unnamed: 3  \
# 0     S. No.  Candidate Name     Counselor Name  Block Amount Received Date
# 1          1          Vikash  Shailendra Singh                        45152
# 2          2         Hariraj  Shailendra Singh                        45188
# 3          3        Thippesh  Shailendra Singh                        45190
# 4          4         Chintan  Shailendra Singh                        45202
# 5          5           Sagar  Shailendra Singh                        45181
# 6          6            Amir  Shailendra Singh                        45146
# 7          7         Sudheer  Shailendra Singh                        45168
# 8          8          Saumya  Shailendra Singh                        45205
# 9          9     Pushpalatha  Shailendra Singh                        45187
#
#          Unnamed: 4 Unnamed: 5                                    Unnamed: 6  \
# ...
