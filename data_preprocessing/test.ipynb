# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %%
import numpy as np
np.__version__
# Out:
# '2.0.0'

# %%
df = pd.DataFrame(pd.read_csv("F:\LPU\Data\WA_Fn-UseC_-Telco-Customer-Churn.csv"))
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\L'
# <>:1: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\SIDDHARTH\AppData\Local\Temp\ipykernel_14220\219053293.py:1: SyntaxWarning: invalid escape sequence '\L'
#   df = pd.DataFrame(pd.read_csv("F:\LPU\Data\WA_Fn-UseC_-Telco-Customer-Churn.csv"))

# %%
df.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  7590-VHVEG  Female              0     Yes         No       1
# 1  5575-GNVDE    Male              0      No         No      34
# 2  3668-QPYBK    Male              0      No         No       2
# 3  7795-CFOCW    Male              0      No         No      45
# 4  9237-HQITU  Female              0      No         No       2
#
#   PhoneService(landline)     MultipleLines InternetService OnlineSecurity  \
# 0                     No  No phone service             DSL             No
# 1                    Yes                No             DSL            Yes
# 2                    Yes                No             DSL            Yes
# 3                     No  No phone service             DSL            Yes
# 4                    Yes                No     Fiber optic             No
#
#    ... DeviceProtection TechSupport StreamingTV StreamingMovies  \
# 0  ...               No          No          No              No
# ...

# %%
print(f"Is there any null values in 'customerID' column : {df['customerID'].duplicated().any()}")
print(f"No of null values in the 'customerID column : {df['customerID'].isnull().sum()}")
# Out:
# Is there any null values in 'customerID' column : False
# No of null values in the 'customerID column : 0

# %%
df.dtypes
# Out:
# customerID                 object
# gender                     object
# SeniorCitizen               int64
# Partner                    object
# Dependents                 object
# tenure                      int64
# PhoneService(landline)     object
# MultipleLines              object
# InternetService            object
# OnlineSecurity             object
# OnlineBackup               object
# DeviceProtection           object
# TechSupport                object
# StreamingTV                object
# StreamingMovies            object
# Contract                   object
# PaperlessBilling           object
# PaymentMethod              object
# MonthlyCharges            float64
# TotalCharges              float64
# Churn                      object
# dtype: object

# %%
df['TotalCharges'].replace(' ','0')
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %%
print(df['customerID'].duplicated().sum())
# Out:
# 0

# %%
df.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  7590-VHVEG  Female              0     Yes         No       1
# 1  5575-GNVDE    Male              0      No         No      34
# 2  3668-QPYBK    Male              0      No         No       2
# 3  7795-CFOCW    Male              0      No         No      45
# 4  9237-HQITU  Female              0      No         No       2
#
#   PhoneService(landline)     MultipleLines InternetService OnlineSecurity  \
# 0                     No  No phone service             DSL             No
# 1                    Yes                No             DSL            Yes
# 2                    Yes                No             DSL            Yes
# 3                     No  No phone service             DSL            Yes
# 4                    Yes                No     Fiber optic             No
#
#    ... DeviceProtection TechSupport StreamingTV StreamingMovies  \
# 0  ...               No          No          No              No
# ...

# %%
df['Partner'].value_counts()
# Out:
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(df)
plt.show()

# %%
plt.scatter(df['TotalCharges'],df['TotalCharges'])

# %%
plt.scatter(df['MonthlyCharges'],df['MonthlyCharges'])

# %%
plt.scatter(df['tenure'],df['tenure'])

# %%
plt.scatter(df['SeniorCitizen'],df['SeniorCitizen'])

# %%
(df['TotalCharges'] == 0).sum()
# Out:
# np.int64(11)

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
val = df['TotalCharges'].value_counts().sort_index()
val
# Out:
# TotalCharges
# 0.00       11
# 18.80       1
# 18.85       2
# 18.90       1
# 19.00       1
#            ..
# 8564.75     1
# 8594.40     1
# 8670.10     1
# 8672.45     1
# 8684.80     1
# Name: count, Length: 6531, dtype: int64

# %%
plt.figure(figsize=(6, 6))
plt.bar(val.index, val.values)
plt.xlabel('TotalCharges')
plt.ylabel('Count')
plt.title('Count of Each Unique Value in TotalCharges')
plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(x=df['Partner'].index, y=df['Partner'].values)
# Out:
# <Axes: xlabel='None'>

# %%
df['MonthlyCharges'] = pd.to_numeric(df['MonthlyCharges'], errors='coerce')
df['tenure'] = pd.to_numeric(df['tenure'], errors='coerce')
df['SeniorCitizen'] = pd.to_numeric(df['SeniorCitizen'], errors='coerce')

categorical_columns = df.select_dtypes(include=['object', 'category']).columns

# Debug: Print the categorical columns
print("Categorical columns:", categorical_columns)
# Out:
# Categorical columns: Index(['customerID', 'gender', 'Partner', 'Dependents',
#        'PhoneService(landline)', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'Churn'],
#       dtype='object')

# %%
value_counts = df['gender'].value_counts()
sns.barplot(x=value_counts.index, y=value_counts.values, palette='viridis')
# Out:
# C:\Users\SIDDHARTH\AppData\Local\Temp\ipykernel_14220\638931656.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=value_counts.index, y=value_counts.values, palette='viridis')
# <Axes: xlabel='gender'>

# %%
value_counts = df['Partner'].value_counts()
sns.barplot(x=value_counts.index, y=value_counts.values, palette='viridis')
# Out:
# C:\Users\SIDDHARTH\AppData\Local\Temp\ipykernel_14220\1169539596.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=value_counts.index, y=value_counts.values, palette='viridis')
# <Axes: xlabel='Partner'>

# %%
value_counts = df['InternetService'].value_counts()
sns.barplot(x=value_counts.index, y=value_counts.values, palette='viridis')
# Out:
# C:\Users\SIDDHARTH\AppData\Local\Temp\ipykernel_14220\1875962753.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=value_counts.index, y=value_counts.values, palette='viridis')
# <Axes: xlabel='InternetService'>

# %%
value_counts = df['Churn'].value_counts()
sns.barplot(x=value_counts.index, y=value_counts.values, palette='viridis')
# Out:
# C:\Users\SIDDHARTH\AppData\Local\Temp\ipykernel_14220\1491408083.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=value_counts.index, y=value_counts.values, palette='viridis')
# <Axes: xlabel='Churn'>
