# %%
import pandas as pd

# %%
data = pd.read_csv(r"F:\LPU\Data\Urban Company dataset\ubc.csv")

# %%
data
# Out:
#              Column1         City Country Customer ID     Customer Name  \
# 0          Furniture        Jammu   India   DV-134651  Dianna Vittorini
# 1    Office Supplies     Jabalpur   India   CC-124301       Chuck Clark
# 2    Office Supplies    Hyderabad   India   NM-184451      Nathan Mautz
# 3    Office Supplies    Hyderabad   India   AA-106451     Anna Andreadi
# 4    Office Supplies    Bangalore   India   SP-208601          Sung Pak
# ..               ...          ...     ...         ...               ...
# 294        Furniture  Muzaffarpur   India   BT-115301   Bradley Talbott
# 295        Furniture         Pune   India   HP-148151     Harold Pawlan
# 296  Office Supplies         Pune   India   HP-148151     Harold Pawlan
# 297  Office Supplies         Pune   India   HP-148151     Harold Pawlan
# 298  Office Supplies   Coimbatore   India   JO-151451     Jack O'Briant
#
#     Market  Order Date       Order ID Order Priority       Product ID  ...  \
# ...

# %%
df = pd.DataFrame(data)

# %%
df.head(5)
# Out:
#            Column1       City Country Customer ID     Customer Name Market  \
# 0        Furniture      Jammu   India   DV-134651  Dianna Vittorini   APAC
# 1  Office Supplies   Jabalpur   India   CC-124301       Chuck Clark   APAC
# 2  Office Supplies  Hyderabad   India   NM-184451      Nathan Mautz   APAC
# 3  Office Supplies  Hyderabad   India   AA-106451     Anna Andreadi   APAC
# 4  Office Supplies  Bangalore   India   SP-208601          Sung Pak   APAC
#
#    Order Date       Order ID Order Priority       Product ID  ... Ship Date  \
# 0       40554  IN-2011-29872           High  FUR-FU-10001471  ...     40558
# 1       40567  IN-2011-10552         Medium  OFF-LA-10004430  ...     40573
# 2       40569  IN-2011-31496           High  OFF-PA-10000070  ...     40571
# 3       40569  IN-2011-76198            Low  OFF-AR-10002256  ...     40575
# 4       40585  IN-2011-60917           High  OFF-BI-10001659  ...     40589
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Column1            299 non-null    object
#  1   City               299 non-null    object
#  2   Country            299 non-null    object
#  3   Customer ID        299 non-null    object
#  4   Customer Name      299 non-null    object
#  5   Market             299 non-null    object
#  6   Order Date         299 non-null    int64
#  7   Order ID           299 non-null    object
#  8   Order Priority     299 non-null    object
#  9   Product ID         299 non-null    object
#  10  Product Name       299 non-null    object
#  11  Region             299 non-null    object
#  12  Row ID             299 non-null    int64
#  13  Segment            299 non-null    object
#  14  Ship Date          299 non-null    int64
#  15  Ship Mode          299 non-null    object
# ...

# %%
df.describe()
# Out:
#          Order Date        Row ID     Ship Date    Discount  \
# count    299.000000    299.000000    299.000000  299.000000
# mean   40802.324415  25404.662207  40806.317726    0.020067
# std      101.079667   2947.706188    101.042067    0.098301
# min    40554.000000  20300.000000  40558.000000    0.000000
# 25%    40727.000000  22497.500000  40731.000000    0.000000
# 50%    40812.000000  25591.000000  40816.000000    0.000000
# 75%    40882.500000  27858.500000  40887.000000    0.000000
# max    40971.000000  30283.000000  40977.000000    0.500000
#
#        Number of Records      Profit    Quantity        Sales  Shipping Cost
# count              299.0  299.000000  299.000000   299.000000     299.000000
# mean                 1.0   82.464833    3.632107   406.899666      43.190635
# std                  0.0  143.631681    1.975973   693.215973      83.527461
# min                  1.0 -215.100000    1.000000     7.000000       0.090000
# ...

# %%
print("No of missing values per each column:")
df.isnull().sum()
# Out:
# No of missing values per each column:
# Column1              0
# City                 0
# Country              0
# Customer ID          0
# Customer Name        0
# Market               0
# Order Date           0
# Order ID             0
# Order Priority       0
# Product ID           0
# Product Name         0
# Region               0
# Row ID               0
# Segment              0
# Ship Date            0
# Ship Mode            0
# State                0
# Sub-Category         0
# Discount             0
# Number of Records    0
# Profit               0
# Quantity             0
# Sales                0
# Shipping Cost        0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Column1', 'City', 'Country', 'Customer ID', 'Customer Name', 'Market',
#        'Order Date', 'Order ID', 'Order Priority', 'Product ID',
#        'Product Name', 'Region', 'Row ID', 'Segment', 'Ship Date', 'Ship Mode',
#        'State', 'Sub-Category', 'Discount', 'Number of Records', 'Profit',
#        'Quantity', 'Sales', 'Shipping Cost'],
#       dtype='object')

# %%
df.describe()
# Out:
#          Order Date        Row ID     Ship Date    Discount  \
# count    299.000000    299.000000    299.000000  299.000000
# mean   40802.324415  25404.662207  40806.317726    0.020067
# std      101.079667   2947.706188    101.042067    0.098301
# min    40554.000000  20300.000000  40558.000000    0.000000
# 25%    40727.000000  22497.500000  40731.000000    0.000000
# 50%    40812.000000  25591.000000  40816.000000    0.000000
# 75%    40882.500000  27858.500000  40887.000000    0.000000
# max    40971.000000  30283.000000  40977.000000    0.500000
#
#        Number of Records      Profit    Quantity        Sales  Shipping Cost
# count              299.0  299.000000  299.000000   299.000000     299.000000
# mean                 1.0   82.464833    3.632107   406.899666      43.190635
# std                  0.0  143.631681    1.975973   693.215973      83.527461
# min                  1.0 -215.100000    1.000000     7.000000       0.090000
# ...

# %%
df.dtypes
# Out:
# Column1               object
# City                  object
# Country               object
# Customer ID           object
# Customer Name         object
# Market                object
# Order Date             int64
# Order ID              object
# Order Priority        object
# Product ID            object
# Product Name          object
# Region                object
# Row ID                 int64
# Segment               object
# Ship Date              int64
# Ship Mode             object
# State                 object
# Sub-Category          object
# Discount             float64
# Number of Records      int64
# Profit               float64
# Quantity               int64
# Sales                  int64
# Shipping Cost        float64
# dtype: object

# %%
df.astype(str)
# Out:
#              Column1         City Country Customer ID     Customer Name  \
# 0          Furniture        Jammu   India   DV-134651  Dianna Vittorini
# 1    Office Supplies     Jabalpur   India   CC-124301       Chuck Clark
# 2    Office Supplies    Hyderabad   India   NM-184451      Nathan Mautz
# 3    Office Supplies    Hyderabad   India   AA-106451     Anna Andreadi
# 4    Office Supplies    Bangalore   India   SP-208601          Sung Pak
# ..               ...          ...     ...         ...               ...
# 294        Furniture  Muzaffarpur   India   BT-115301   Bradley Talbott
# 295        Furniture         Pune   India   HP-148151     Harold Pawlan
# 296  Office Supplies         Pune   India   HP-148151     Harold Pawlan
# 297  Office Supplies         Pune   India   HP-148151     Harold Pawlan
# 298  Office Supplies   Coimbatore   India   JO-151451     Jack O'Briant
#
#     Market Order Date       Order ID Order Priority       Product ID  ...  \
# ...

# %%
df.dtypes
# Out:
# Column1               object
# City                  object
# Country               object
# Customer ID           object
# Customer Name         object
# Market                object
# Order Date             int64
# Order ID              object
# Order Priority        object
# Product ID            object
# Product Name          object
# Region                object
# Row ID                 int64
# Segment               object
# Ship Date              int64
# Ship Mode             object
# State                 object
# Sub-Category          object
# Discount             float64
# Number of Records      int64
# Profit               float64
# Quantity               int64
# Sales                  int64
# Shipping Cost        float64
# dtype: object

# %%
city_count = df['City'].value_counts()

# %%
city_count
# Out:
# Delhi        12
# Raipur       12
# Mumbai       12
# Pune         11
# Agra         10
#              ..
# Hapur         1
# Bhilwara      1
# Brahmapur     1
# Dewas         1
# Jammu         1
# Name: City, Length: 81, dtype: int64

# %%
f"Total number of cities: {len(city_count)}"
# Out:
# 'Total number of cities: 81'

# %%
sub = df['Sub-Category'].value_counts()

# %%
sub
# Out:
# Binders        29
# Accessories    25
# Phones         24
# Bookcases      22
# Furnishings    21
# Fasteners      21
# Chairs         20
# Paper          19
# Labels         19
# Envelopes      19
# Storage        18
# Supplies       18
# Copiers        16
# Art            11
# Machines        8
# Appliances      5
# Tables          4
# Name: Sub-Category, dtype: int64

# %%
f"Total no of subcategories: {len(sub)}"
# Out:
# 'Total no of subcategories: 17'

# %%
product = df['Product ID'].unique()

# %%
product = pd.DataFrame(product)
product.head()
# Out:
#                  0
# 0  FUR-FU-10001471
# 1  OFF-LA-10004430
# 2  OFF-PA-10000070
# 3  OFF-AR-10002256
# 4  OFF-BI-10001659

# %%
len(product)
# Out:
# 277

# %%
ship = df['Ship Mode'].unique()

# %%
print(ship)
# Out:
# ['Standard Class' 'Second Class' 'First Class' 'Same Day']

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    187
# Second Class       59
# First Class        38
# Same Day           15
# Name: Ship Mode, dtype: int64

# %%
df['Order Priority'].value_counts()
# Out:
# Medium      181
# High         69
# Critical     37
# Low          12
# Name: Order Priority, dtype: int64
